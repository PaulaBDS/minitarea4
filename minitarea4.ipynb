# %% [markdown]
# <a href="https://colab.research.google.com/github/PaulaBDS/minitarea4/blob/master/minitarea4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #EI2001 : Ciencia de Datos en Astronomía
# **Profesores:** Pía Cortés, Daniela Barrientos, Matías Mattamala, Matías Suazo
#
# ##Minitarea 4: Análisis de Cubo de datos extragaláctico y querys.
#
# ###Objetivos:
# 1. Utilizar el paquete **astropy** para trabajar con unidades de medidas, coordenadas y fits.
# 2. Utilizar datos del google drive personal de cada uno.
# 3. Lectura de archivos *fits* en objetos extragalácticos en forma de cubo de datos.
# 4. Utilizar el paquete **astroquery** para hacer query de objetos del SDSS.

# %% [markdown]
# ###Instrucciones:
#
# 1. Lean cuidadosamente todo lo que viene ahora
# 2. Para hacer esta tarea deben que hacer un **fork** del repositorio en sus cuentas de GitHub.
# 3. Abrir [Google Colab](https://colab.research.google.com/) y seleccionar "abrir un archivo desde GitHub". Deben seleccionar su cuenta Github y escoger el repositorio que corresponde al fork que hicieron.
# 4. Si todo sale bien, debería abrirse una copia de este notebook en su cuenta de Google Colab.
# 5. Se adjuntan 6 mini actividades a completar. **TODAS** son necesarias y deben completar lo que se va pidiendo.
# 6. Cada vez que completen un ítem, deben guardar un avance en su fork de GitHub, de modo de **respaldar cada avance significativo**. Usen comentarios coherentes con cada respaldo "Sección 1 completa", "Tarea terminada", no solamente el que pone por defecto.

# %% [markdown]
# #1. FITS en Google Drive.
#
# En el siguiente enlace [(link)](https://docs.google.com/spreadsheets/d/1lT4h9Evwm6i2SBeuCK5dESTm8FijVZX7r6ixq-dt3ZM/edit#gid=0) se encuentra un excel con 30 galaxias observadas con CALIFA usando la técnica de Integral Field Spectroscopy (IFS). Debe escoger una galaxia que se encuentre disponible anotando su nombre en la casilla correspondiente a la galaxia que desee escoger (**No puede elegir una ya escojida por alguien más**). A cada galaxia le corresponde un link con el cual se pueden descargar los datos obtenidos por CALIFA para dicha galaxia en un cubo de datos **fits.gz**.
#
# Descargue el archivo correspondiente y súbalo a la cuenta de Google Drive vinculada con la cuenta de Google que utiliza para trabajar con [Google Colab](https://colab.research.google.com/). Asegúrese que el archivo de descarga corresponde con la galaxia seleccionada, en caso contrario hágalo saber al equipo docente.
#
# Ahora importe los paquetes y funciones necesarias vistas en clases para poder montar su unidad de Google drive. Si lo hace correctamente debiese aparecer un mensaje. Verifique que se muestra al correr esas líneas de código.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# # 2. Visualización de la Galaxia
#
# En esta parte debe hacer lectura del cubo de datos **fits.gz** que se encuentra guardado en su Google Drive. Importe todos los paquetes que sean necesarios, no olvide leer el header (Ya sea en su forma normal o en WCS) e imprímalo en pantalla.

# %%
from astropy.io import fits
from astropy.wcs import WCS
import matplotlib.pyplot as plt
import numpy as np

file = ('/content/gdrive/My Drive/NGC7819.V500.rscube.fits.gz')
hdu = fits.open(file)[0]
header = hdu.header
wcs = WCS(header)
print(wcs)
print('\nHEADER:\n')
header
# Out:
# WCS Keywords
#
# Number of WCS axes: 3
# CTYPE : 'RA---TAN'  'DEC--TAN'  'WAVELENGTH'
# CRVAL : 1.101693322322549  31.47187616999986  3749.0
# CRPIX : 34.0  33.0  1.0
# CD1_1 CD1_2 CD1_3  : -0.00027777777777777  0.0  0.0
# CD2_1 CD2_2 CD2_3  : 0.0  0.000277777777777777  0.0
# CD3_1 CD3_2 CD3_3  : 0.0  0.0  2.0
# NAXIS : 78  72  1877
#
# HEADER:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                  -32 / number of bits per data pixel
# NAXIS   =                    3 / number of data axes
# NAXIS1  =                   78 / length of data axis 1
# NAXIS2  =                   72 / length of data axis 2
# NAXIS3  =                 1877
# EXTEND  =                    T / FITS dataset may contain extensions
# HIERARCH V500 PPAK P1 LONGSTRN = 'OGIP 1.0' / The HEASARC Long String Convention
# HIERARCH V500 PPAK P1 PVERSION = '1.0     ' / PMAS fitsheader version
# HIERARCH V500 PPAK P1 FILENAME = 'run196_00956a.fits' / original filename
# HIERARCH V500 PPAK P1 DATE = '2011-09-25T23:04:34' / file creation
# HIERARCH V500 PPAK P1 OBSERVER = 'Montoya -- Sanchez'
# HIERARCH V500 PPAK P1 OBJECT = 'obj_5_p1_NGC 7819'
# HIERARCH V500 PPAK P1 CCD_TYPE = 'CCD231  '
# HIERARCH V500 PPAK P1 NAMPS = 4 / Number of Amplifiers
# HIERARCH V500 PPAK P1 NCCDS = 1 / Number of CCDs
# HIERARCH V500 PPAK P1 CAMPOS = -856.0 / camera position
# HIERARCH V500 PPAK P1 COLPOS = 101.0 / collimator position
# HIERARCH V500 PPAK P1 GROTPOS = 143.8 / grating position
# HIERARCH V500 PPAK P1 DEWAR = -117.072 / dewar temperature
# HIERARCH V500 PPAK P1 CALPOS = 120.0 / CAL actual position
# HIERARCH V500 PPAK P1 AGPOS = 3.1961E-05 / AG actual position
# HIERARCH V500 PPAK P1 FOCOLPOS = -8.2479900000000E-06 / FOCOL actual enc. positi
# HIERARCH V500 PPAK P1 FOFEPOS = 0.0 / FO Filter actual enc. position
# HIERARCH V500 PPAK P1 FOZPOS = 0.000331395 / FOZ stage actual enc. position
# HIERARCH V500 PPAK P1 FOCOLSL = 'none    ' / FO Collimator selection
# HIERARCH V500 PPAK P1 FOFESL = 'none    ' / FO Filter selection
# HIERARCH V500 PPAK P1 FIRST_AG = 16473 / A&G frame at begin of SPEC exposure
# HIERARCH V500 PPAK P1 DATE-OBS = '2011-09-25T23:04:34' / file creation
# HIERARCH V500 PPAK P1 POSTN-RA = 317.4 / tel. position Right Ascension
# HIERARCH V500 PPAK P1 RA = 1.322492 / 00:05:17.4 RA [deg]
# HIERARCH V500 PPAK P1 POSTN-DE = 113845.28 / tel. position Declination
# HIERARCH V500 PPAK P1 DEC = 31.62369 / +31:37:25.3 DEC [deg]
# HIERARCH V500 PPAK P1 POSTN-HA = 83204.13 / tel. position Hour Angle
# HIERARCH V500 PPAK P1 HA = 346.683889 / 23:06:44.1 HA [deg]
# HIERARCH V500 PPAK P1 UNI-TIME = 83073.33 / Universal Time
# HIERARCH V500 PPAK P1 UTC = 83073.33302999999 / 23:04:33.3 U.T. at start [sec]
# HIERARCH V500 PPAK P1 UT_START = 83073.33302999999 / 23:04:33.3 U.T. at start [s
# HIERARCH V500 PPAK P1 SID-TIME = 83521.7 / Sidereal Time [sec]
# HIERARCH V500 PPAK P1 LST = 83521.70374899999 / 23:12:01.7 sid. time [sec]
# HIERARCH V500 PPAK P1 AIRMASS = 1.02363 / airmass
# HIERARCH V500 PPAK P1 JUL-DATE = 2455830.4635 / julian date
# HIERARCH V500 PPAK P1 MJD-OBS = 55829.96352829 / modified jul. date
# HIERARCH V500 PPAK P1 CAHA TEL GEOELEV = 2168 / elev. above sea
# HIERARCH V500 PPAK P1 CAHA TEL GEOLAT = 37.2236 / geographic lat.
# HIERARCH V500 PPAK P1 CAHA TEL GEOLON = -2.5463 / geographic long.
# HIERARCH V500 PPAK P1 CAHA TEL DOME.AZ = 290.1 / dome azimut [degr]
# HIERARCH V500 PPAK P1 CAHA TEL DOME.EL_LOW_E = 73.0 / dome door low lim.
# HIERARCH V500 PPAK P1 CAHA TEL DOME EL_UPP_E = 92.0 / dome door upper lim.
# HIERARCH V500 PPAK P1 CAHA TEL FOCU ID = 'CASS    ' / ID of used focus
# HIERARCH V500 PPAK P1 CAHA TEL MIRR S1 COLLAREA = 0.92 / eff. coll. area of S1 [
# HIERARCH V500 PPAK P1 CAHA TEL FOCU F_RATIO = 8.0 / f-ratio
# HIERARCH V500 PPAK P1 CAHA TEL FOCU LEN = 9.808 / focal length [m]
# HIERARCH V500 PPAK P1 CAHA TEL FOCU SCALE = 0.0478 / focus scale mm/arcsec
# HIERARCH V500 PPAK P1 CAHA TEL FOCU VALUE = 30.804 / focus rel. setting
# HIERARCH V500 PPAK P1 CAHA TEL POS SET RA = 495420.0 / 09:10:28.0 RA preset [sec
# HIERARCH V500 PPAK P1 CAHA TEL POS SET DEC = 46.439722 / +46:26:23.0 DEC preset
# HIERARCH V500 PPAK P1 CAHA TEL POS SET EQUINOX = 1950.0 / eq preset
# HIERARCH V500 PPAK P1 CAHA TEL POS AZ_START = 293.11 / telescope azimuth at star
# HIERARCH V500 PPAK P1 CAHA TEL POS EL_START = 77.69 / telescope elevation at sta
# HIERARCH V500 PPAK P1 CAHA TEL POS HA_START = 346.683889 / 23:06:44.1 HA [deg]
# HIERARCH V500 PPAK P1 CAHA GEN AMBI WIND SPEED = 3.4 / wind-speed[m/s]
# HIERARCH V500 PPAK P1 CAHA GEN AMBI WIND DIR = 84 / wind dir[deg.]
# HIERARCH V500 PPAK P1 CAHA GEN AMBI RHUM = 55 / relative humidity[%]
# HIERARCH V500 PPAK P1 CAHA GEN AMBI PRES = 780.6 / air pressure
# HIERARCH V500 PPAK P1 CAHA GEN AMBI TEMP = 10.3 / air-temperature[Celsius]
# HIERARCH V500 PPAK P1 CAHA ADA POSANG = -2707.5 / position angle of adapter
# HIERARCH V500 PPAK P1 XBIN = 2 / x binning
# HIERARCH V500 PPAK P1 YBIN = 2 / y binning
# HIERARCH V500 PPAK P1 ACEGAIN = 5 / ace gain
# HIERARCH V500 PPAK P1 CDSTIME = 1 / ace cds time
# HIERARCH V500 PPAK P1 EXPTIME = 900 / exposure time [s]
# HIERARCH V500 PPAK P1 EXPTIMEM = 0 / exposure time [ms]
# HIERARCH V500 PPAK P1 EXPTYPE = 1 / exposure type 0
# HIERARCH V500 PPAK P1 LMPSH_1 = 0 / shutter lamp 1 (Hal)
# HIERARCH V500 PPAK P1 LMPSH_2 = 0 / shutter lamp 2 (Ne)
# HIERARCH V500 PPAK P1 LMPSH_3 = 0 / shutter lamp 3 (Ne
# HIERARCH V500 PPAK P1 LMPSH_4 = 0 / shutter lamp 4 (Hg)
# HIERARCH V500 PPAK P1 LMPSH_5 = 0 / shutter lamp 5 (Hg)
# HIERARCH V500 PPAK P1 LMPSH_6 = 0 / shutter lamp 6 (ThAr)
# HIERARCH V500 PPAK P1 PPAK_SH3 = 0 / PPAK CALUNIT Shutter
# HIERARCH V500 PPAK P1 LMPOW_1 = 0 / power lamp 1 (Hal)
# HIERARCH V500 PPAK P1 LMPOW_23 = 0 / power lamp 2+3 (Ne)
# HIERARCH V500 PPAK P1 LMPOW_45 = 0 / power lamp 4+5 (Hg)
# HIERARCH V500 PPAK P1 LMPOW_6 = 0 / power lamp 6 (ThAr)
# HIERARCH V500 PPAK P1 POLUNIT = 0 / polarimetric mode 1
# HIERARCH V500 PPAK P1 POLANGL1 = 0.0 / polarimeter angle 1
# HIERARCH V500 PPAK P1 POLANGL2 = 22.5 / polarimeter angle 2
# HIERARCH V500 PPAK P1 GRAT_ID = 9 / grating id
# HIERARCH V500 PPAK P1 NFIBERS = 382 / number of fibers
# HIERARCH V500 PPAK P1 IFU_TYPE = 'PPAK_GenI.1_DIFU_331_36_15' / type of int. fie
# HIERARCH V500 PPAK P1 IFU_CONF = 'PPAK_GenI.1_DIFU_331_36_15.ifu' / configuratio
# HIERARCH V500 PPAK P1 PPAK_FIL = 'none    ' / PPAK IFU FORED Filter
# HIERARCH V500 PPAK P1 PPAK_CUF = 'none    ' / PPAK Calibration Unit Filter
# HIERARCH V500 PPAK P1 PPAK_SHO = 0.0 / PPAK Calibration Shutter open time
# HIERARCH V500 PPAK P1 LAST_AG = 16543 / A&G frame at end of SPEC exposure
# HIERARCH V500 PPAK P1 WARNING = 'Warning ' / RON & GAIN are measured unbinned!
# HIERARCH V500 PPAK P1 CAHA TEL POS AZ_END = 302.62 / telescope azimuth at end [d
# HIERARCH V500 PPAK P1 CAHA TEL POS EL_END = 80.34 / telescope elevation at end [
# HIERARCH V500 PPAK P1 CAHA TEL POS HA_END = 350.450556 / 23:21:48.1 HA [deg] at
# HIERARCH V500 PPAK P1 UT_END = 83974.83302999999 / 23:19:34.8 U.T. [sec]
# HIERARCH V500 PPAK P1 EXPOSURE_TIME = 900.0 / s exposure time
# HIERARCH V500 PPAK P1 IMAGETYP = 'real    ' / bias,real,dark,test,ramp,bsw
# HIERARCH V500 PPAK P1 DETSIZE = '[1:4096,1:4112]' / physical detector size
# HIERARCH V500 PPAK P1 PRESCAN = '[50,0]  ' / additional real existent prescan pi
# HIERARCH V500 PPAK P1 CCDSEC = '[1:1055,1:1035]' / image location of amplifier
# HIERARCH V500 PPAK P1 AMP1 GAIN = 1.293 / Gain value of CCD amplifier 1
# HIERARCH V500 PPAK P1 AMP2 GAIN = 1.148 / Gain value of CCD amplifier 2
# HIERARCH V500 PPAK P1 AMP3 GAIN = 1.286 / Gain value of CCD amplifier 3
# HIERARCH V500 PPAK P1 AMP4 GAIN = 1.25 / Gain value of CCD amplifier 4
# HIERARCH V500 PPAK P1 AMP1 RDNOISE = 2.877 / Read-out noise of CCD amplifier 1
# HIERARCH V500 PPAK P1 AMP2 RDNOISE = 2.73 / Read-out noise of CCD amplifier 2
# HIERARCH V500 PPAK P1 AMP3 RDNOISE = 2.855 / Read-out noise of CCD amplifier 3
# HIERARCH V500 PPAK P1 AMP4 RDNOISE = 2.57 / Read-out noise of CCD amplifier 4
# HIERARCH V500 PPAK P1 AMP1 OVERSCAN = 363.0 / Overscan median (bias) of CCD ampl
# HIERARCH V500 PPAK P1 AMP2 OVERSCAN = 497.0 / Overscan median (bias) of CCD ampl
# HIERARCH V500 PPAK P1 AMP3 OVERSCAN = 551.0 / Overscan median (bias) of CCD ampl
# HIERARCH V500 PPAK P1 AMP4 OVERSCAN = 561.0 / Overscan median (bias) of CCD ampl
# HIERARCH V500 PPAK P1 HVCOR = 5.41 / Heliocentric vel correction [km/s]
# HIERARCH V500 PPAK P1 EXT_V = 0.17 / V-band atmospheric extinction
# HIERARCH V500 PPAK P1 EXT_V_SD = 0.0 / std of V-band atmospheric extinction
# HIERARCH V500 PPAK P1 PIPE FLEX YOFF = -0.0012 / flexure offset in y-direction
# HIERARCH V500 PPAK P1 PIPE FLEX YRMS = '0.1005  ' / flexure rms in y-direction
# DISPAXIS=                    3
# HIERARCH V500 PPAK P1 PIPE CDISP FWHM MIN = 2.263823986053467
# HIERARCH V500 PPAK P1 PIPE CDISP FWHM MAX = 4.0
# HIERARCH V500 PPAK P1 PIPE CDISP FWHM AVG = 2.592828152939799
# HIERARCH V500 PPAK P1 PIPE CDISP FWHM MED = 2.528854846954346
# HIERARCH V500 PPAK P1 PIPE CDISP FWHM SIG = 0.2371905739189109
# HIERARCH V500 PPAK P1 PIPE DISP RMS MEDIAN = '0.0800  ' / Median RMS of disp sol
# HIERARCH V500 PPAK P1 PIPE DISP RMS MIN = '0.0224  ' / Min RMS of disp sol
# HIERARCH V500 PPAK P1 PIPE DISP RMS MAX = '0.4389  ' / Max RMS of disp sol
# HIERARCH V500 PPAK P1 PIPE FLEX XOFF = -0.0312 / flexure offset in x-direction
# HIERARCH V500 PPAK P1 PIPE FLEX XRMS = 0.2073 / flexure rms in x-direction
# HIERARCH V500 PPAK P1 PIPE SPEC RES = 6.0 / FWHM in A of spectral resolution
# CRVAL1  =    1.101693322322549 / RA at CRPIX1 in deg
# CDELT1  =                  1.0
# CRPIX1  =                   34 / Ref pixel for WCS
# HIERARCH V500 PPAK P1 PIPE NSKY FIB = 30 / Number of averaged sky fibers
# HIERARCH V500 PPAK P1 PIPE SKY MEAN = 20.83 / Mean sky brightness of sky fibers
# HIERARCH V500 PPAK P1 PIPE SKY MIN = 20.75 / Minium sky brightness of sky fibers
# HIERARCH V500 PPAK P1 PIPE SKY MAX = 20.94 / Maximum sky brightness of sky fiber
# HIERARCH V500 PPAK P1 PIPE SKY RMS = 0.03 / RMS sky brightness of sky fibers
# HIERARCH V500 PPAK P1 PIPE CONT = 'run196_00954.fits' / Name of the continuum fr
# HIERARCH V500 PPAK P1 PIPE CONT MST = 0 / master TRACE used
# HIERARCH V500 PPAK P1 PIPE ARC = 'run196_00955.fits' / Name of the arc frame
# HIERARCH V500 PPAK P1 PIPE ARC MST = 0 / master ARC lamp used
# HIERARCH V500 PPAK P1 PIPE WOFFSET = 0.006 / wavelength offset of OI 5777 sky li
# HIERARCH V500 PPAK P1 PIPE WRMS = 0.064 / offset RMS of OI 5777 sky line
# HIERARCH V500 PIPE P1 APER FLUX = 5.761 / V_Johnson band flux (30.0arcsec diamet
# HIERARCH V500 PIPE P1 APER ERR = 0.065 / V_Johnson band error (30.0arcsec diamet
# HIERARCH V500 PIPE P1 RELFLUX START = 4500.0 / Start wave for poly fit
# HIERARCH V500 PIPE P1 RELFLUX END = 7000.0 / End wave for poly fit
# HIERARCH V500 PIPE P1 RELFLUX POLY0 = '1.070E+00' / Polynomial coefficient
# HIERARCH V500 PIPE P1 RELFLUX POLY1 = '-7.597E-06' / Polynomial coefficient
# HIERARCH V500 PIPE P1 PIPE REGISTER = 1 / Possibilty of registering for this poi
# HIERARCH V500 PIPE P1 PIPE OFFX = -2.75 / IFU RA offset from ref coordinate
# HIERARCH V500 PIPE P1 PIPE OFFY = -4.25 / IFU DEC offset from ref coordinate
# HIERARCH V500 PIPE P1 PIPE CHISQ = 0.23 / CHISQ of image matching
# HIERARCH V500 PIPE P1 PIPE VALIDFIB = 326 / Valid fibers for image matching
# HIERARCH V500 PIPE P1 PIPE PHOTSCL = 0.895 / photometric scale factor
# HIERARCH V500 PPAK P2 LONGSTRN = 'OGIP 1.0' / The HEASARC Long String Convention
# HIERARCH V500 PPAK P2 PVERSION = '1.0     ' / PMAS fitsheader version
# HIERARCH V500 PPAK P2 FILENAME = 'run196_00957a.fits' / original filename
# HIERARCH V500 PPAK P2 DATE = '2011-09-25T23:20:59' / file creation
# HIERARCH V500 PPAK P2 OBSERVER = 'Montoya -- Sanchez'
# HIERARCH V500 PPAK P2 OBJECT = 'obj_5_p2_NGC 7819'
# HIERARCH V500 PPAK P2 CCD_TYPE = 'CCD231  '
# HIERARCH V500 PPAK P2 NAMPS = 4 / Number of Amplifiers
# HIERARCH V500 PPAK P2 NCCDS = 1 / Number of CCDs
# HIERARCH V500 PPAK P2 CAMPOS = -856.0 / camera position
# HIERARCH V500 PPAK P2 COLPOS = 100.0 / collimator position
# HIERARCH V500 PPAK P2 GROTPOS = 143.8 / grating position
# HIERARCH V500 PPAK P2 DEWAR = -117.333 / dewar temperature
# HIERARCH V500 PPAK P2 CALPOS = 120.0 / CAL actual position
# HIERARCH V500 PPAK P2 AGPOS = 3.1961E-05 / AG actual position
# HIERARCH V500 PPAK P2 FOCOLPOS = -8.2479900000000E-06 / FOCOL actual enc. positi
# HIERARCH V500 PPAK P2 FOFEPOS = 0.0 / FO Filter actual enc. position
# HIERARCH V500 PPAK P2 FOZPOS = 0.000331395 / FOZ stage actual enc. position
# HIERARCH V500 PPAK P2 FOCOLSL = 'none    ' / FO Collimator selection
# HIERARCH V500 PPAK P2 FOFESL = 'none    ' / FO Filter selection
# HIERARCH V500 PPAK P2 FIRST_AG = 16547 / A&G frame at begin of SPEC exposure
# HIERARCH V500 PPAK P2 DATE-OBS = '2011-09-25T23:20:59' / file creation
# HIERARCH V500 PPAK P2 POSTN-RA = 316.96 / tel. position Right Ascension
# HIERARCH V500 PPAK P2 RA = 1.320671 / 00:05:17.0 RA [deg]
# HIERARCH V500 PPAK P2 POSTN-DE = 113841.22 / tel. position Declination
# HIERARCH V500 PPAK P2 DEC = 31.62256 / +31:37:21.2 DEC [deg]
# HIERARCH V500 PPAK P2 POSTN-HA = 84192.8 / tel. position Hour Angle
# HIERARCH V500 PPAK P2 HA = 350.803333 / 23:23:12.8 HA [deg]
# HIERARCH V500 PPAK P2 UNI-TIME = 84058.63 / Universal Time
# HIERARCH V500 PPAK P2 UTC = 84058.63303 / 23:20:58.6 U.T. at start [sec]
# HIERARCH V500 PPAK P2 UT_START = 84058.63303 / 23:20:58.6 U.T. at start [sec]
# HIERARCH V500 PPAK P2 SID-TIME = 84509.7 / Sidereal Time [sec]
# HIERARCH V500 PPAK P2 LST = 84509.701411 / 23:28:29.7 sid. time [sec]
# HIERARCH V500 PPAK P2 AIRMASS = 1.01373 / airmass
# HIERARCH V500 PPAK P2 JUL-DATE = 2455830.4749 / julian date
# HIERARCH V500 PPAK P2 MJD-OBS = 55829.97493445 / modified jul. date
# HIERARCH V500 PPAK P2 CAHA TEL GEOELEV = 2168 / elev. above sea
# HIERARCH V500 PPAK P2 CAHA TEL GEOLAT = 37.2236 / geographic lat.
# HIERARCH V500 PPAK P2 CAHA TEL GEOLON = -2.5463 / geographic long.
# HIERARCH V500 PPAK P2 CAHA TEL DOME.AZ = 290.1 / dome azimut [degr]
# HIERARCH V500 PPAK P2 CAHA TEL DOME.EL_LOW_E = 73.0 / dome door low lim.
# HIERARCH V500 PPAK P2 CAHA TEL DOME EL_UPP_E = 92.0 / dome door upper lim.
# HIERARCH V500 PPAK P2 CAHA TEL FOCU ID = 'CASS    ' / ID of used focus
# HIERARCH V500 PPAK P2 CAHA TEL MIRR S1 COLLAREA = 0.92 / eff. coll. area of S1 [
# HIERARCH V500 PPAK P2 CAHA TEL FOCU F_RATIO = 8.0 / f-ratio
# HIERARCH V500 PPAK P2 CAHA TEL FOCU LEN = 9.808 / focal length [m]
# HIERARCH V500 PPAK P2 CAHA TEL FOCU SCALE = 0.0478 / focus scale mm/arcsec
# HIERARCH V500 PPAK P2 CAHA TEL FOCU VALUE = 30.804 / focus rel. setting
# HIERARCH V500 PPAK P2 CAHA TEL POS SET RA = 495420.0 / 09:10:28.0 RA preset [sec
# HIERARCH V500 PPAK P2 CAHA TEL POS SET DEC = 46.439722 / +46:26:23.0 DEC preset
# HIERARCH V500 PPAK P2 CAHA TEL POS SET EQUINOX = 1950.0 / eq preset
# HIERARCH V500 PPAK P2 CAHA TEL POS AZ_START = 303.75 / telescope azimuth at star
# HIERARCH V500 PPAK P2 CAHA TEL POS EL_START = 80.58 / telescope elevation at sta
# HIERARCH V500 PPAK P2 CAHA TEL POS HA_START = 350.803333 / 23:23:12.8 HA [deg]
# HIERARCH V500 PPAK P2 CAHA GEN AMBI WIND SPEED = 4.8 / wind-speed[m/s]
# HIERARCH V500 PPAK P2 CAHA GEN AMBI WIND DIR = 68 / wind dir[deg.]
# HIERARCH V500 PPAK P2 CAHA GEN AMBI RHUM = 52 / relative humidity[%]
# HIERARCH V500 PPAK P2 CAHA GEN AMBI PRES = 780.6 / air pressure
# HIERARCH V500 PPAK P2 CAHA GEN AMBI TEMP = 10.0 / air-temperature[Celsius]
# HIERARCH V500 PPAK P2 CAHA ADA POSANG = 7.88 / position angle of adapter
# HIERARCH V500 PPAK P2 XBIN = 2 / x binning
# HIERARCH V500 PPAK P2 YBIN = 2 / y binning
# HIERARCH V500 PPAK P2 ACEGAIN = 5 / ace gain
# HIERARCH V500 PPAK P2 CDSTIME = 1 / ace cds time
# HIERARCH V500 PPAK P2 EXPTIME = 900 / exposure time [s]
# HIERARCH V500 PPAK P2 EXPTIMEM = 0 / exposure time [ms]
# HIERARCH V500 PPAK P2 EXPTYPE = 1 / exposure type 0
# HIERARCH V500 PPAK P2 LMPSH_1 = 0 / shutter lamp 1 (Hal)
# HIERARCH V500 PPAK P2 LMPSH_2 = 0 / shutter lamp 2 (Ne)
# HIERARCH V500 PPAK P2 LMPSH_3 = 0 / shutter lamp 3 (Ne
# HIERARCH V500 PPAK P2 LMPSH_4 = 0 / shutter lamp 4 (Hg)
# HIERARCH V500 PPAK P2 LMPSH_5 = 0 / shutter lamp 5 (Hg)
# HIERARCH V500 PPAK P2 LMPSH_6 = 0 / shutter lamp 6 (ThAr)
# HIERARCH V500 PPAK P2 PPAK_SH3 = 0 / PPAK CALUNIT Shutter
# HIERARCH V500 PPAK P2 LMPOW_1 = 0 / power lamp 1 (Hal)
# HIERARCH V500 PPAK P2 LMPOW_23 = 0 / power lamp 2+3 (Ne)
# HIERARCH V500 PPAK P2 LMPOW_45 = 0 / power lamp 4+5 (Hg)
# HIERARCH V500 PPAK P2 LMPOW_6 = 0 / power lamp 6 (ThAr)
# HIERARCH V500 PPAK P2 POLUNIT = 0 / polarimetric mode 1
# HIERARCH V500 PPAK P2 POLANGL1 = 0.0 / polarimeter angle 1
# HIERARCH V500 PPAK P2 POLANGL2 = 22.5 / polarimeter angle 2
# HIERARCH V500 PPAK P2 GRAT_ID = 9 / grating id
# HIERARCH V500 PPAK P2 NFIBERS = 382 / number of fibers
# HIERARCH V500 PPAK P2 IFU_TYPE = 'PPAK_GenI.1_DIFU_331_36_15' / type of int. fie
# HIERARCH V500 PPAK P2 IFU_CONF = 'PPAK_GenI.1_DIFU_331_36_15.ifu' / configuratio
# HIERARCH V500 PPAK P2 PPAK_FIL = 'none    ' / PPAK IFU FORED Filter
# HIERARCH V500 PPAK P2 PPAK_CUF = 'none    ' / PPAK Calibration Unit Filter
# HIERARCH V500 PPAK P2 PPAK_SHO = 0.0 / PPAK Calibration Shutter open time
# HIERARCH V500 PPAK P2 LAST_AG = 16616 / A&G frame at end of SPEC exposure
# HIERARCH V500 PPAK P2 WARNING = 'Warning ' / RON & GAIN are measured unbinned!
# HIERARCH V500 PPAK P2 CAHA TEL POS AZ_END = 319.77 / telescope azimuth at end [d
# HIERARCH V500 PPAK P2 CAHA TEL POS EL_END = 82.83 / telescope elevation at end [
# HIERARCH V500 PPAK P2 CAHA TEL POS HA_END = 354.569722 / 23:38:16.7 HA [deg] at
# HIERARCH V500 PPAK P2 UT_END = 84960.18303 / 23:36:00.2 U.T. [sec]
# HIERARCH V500 PPAK P2 EXPOSURE_TIME = 900.0 / s exposure time
# HIERARCH V500 PPAK P2 IMAGETYP = 'real    ' / bias,real,dark,test,ramp,bsw
# HIERARCH V500 PPAK P2 DETSIZE = '[1:4096,1:4112]' / physical detector size
# HIERARCH V500 PPAK P2 PRESCAN = '[50,0]  ' / additional real existent prescan pi
# HIERARCH V500 PPAK P2 CCDSEC = '[1:1055,1:1035]' / image location of amplifier
# HIERARCH V500 PPAK P2 AMP1 GAIN = 1.293 / Gain value of CCD amplifier 1
# HIERARCH V500 PPAK P2 AMP2 GAIN = 1.148 / Gain value of CCD amplifier 2
# HIERARCH V500 PPAK P2 AMP3 GAIN = 1.286 / Gain value of CCD amplifier 3
# HIERARCH V500 PPAK P2 AMP4 GAIN = 1.25 / Gain value of CCD amplifier 4
# HIERARCH V500 PPAK P2 AMP1 RDNOISE = 2.877 / Read-out noise of CCD amplifier 1
# HIERARCH V500 PPAK P2 AMP2 RDNOISE = 2.73 / Read-out noise of CCD amplifier 2
# HIERARCH V500 PPAK P2 AMP3 RDNOISE = 2.855 / Read-out noise of CCD amplifier 3
# HIERARCH V500 PPAK P2 AMP4 RDNOISE = 2.57 / Read-out noise of CCD amplifier 4
# HIERARCH V500 PPAK P2 AMP1 OVERSCAN = 363.0 / Overscan median (bias) of CCD ampl
# HIERARCH V500 PPAK P2 AMP2 OVERSCAN = 497.0 / Overscan median (bias) of CCD ampl
# HIERARCH V500 PPAK P2 AMP3 OVERSCAN = 551.0 / Overscan median (bias) of CCD ampl
# HIERARCH V500 PPAK P2 AMP4 OVERSCAN = 561.0 / Overscan median (bias) of CCD ampl
# HIERARCH V500 PPAK P2 HVCOR = 5.43 / Heliocentric vel correction [km/s]
# HIERARCH V500 PPAK P2 EXT_V = 0.17 / V-band atmospheric extinction
# HIERARCH V500 PPAK P2 EXT_V_SD = 0.0 / std of V-band atmospheric extinction
# HIERARCH V500 PPAK P2 PIPE FLEX YOFF = -0.0169 / flexure offset in y-direction
# HIERARCH V500 PPAK P2 PIPE FLEX YRMS = '0.1001  ' / flexure rms in y-direction
# HIERARCH V500 PPAK P2 PIPE CDISP FWHM MIN = 2.263823986053467
# HIERARCH V500 PPAK P2 PIPE CDISP FWHM MAX = 4.0
# HIERARCH V500 PPAK P2 PIPE CDISP FWHM AVG = 2.592828152939799
# HIERARCH V500 PPAK P2 PIPE CDISP FWHM MED = 2.528854846954346
# HIERARCH V500 PPAK P2 PIPE CDISP FWHM SIG = 0.2371905739189109
# HIERARCH V500 PPAK P2 PIPE DISP RMS MEDIAN = '0.0800  ' / Median RMS of disp sol
# HIERARCH V500 PPAK P2 PIPE DISP RMS MIN = '0.0224  ' / Min RMS of disp sol
# HIERARCH V500 PPAK P2 PIPE DISP RMS MAX = '0.4389  ' / Max RMS of disp sol
# HIERARCH V500 PPAK P2 PIPE FLEX XOFF = -0.0143 / flexure offset in x-direction
# HIERARCH V500 PPAK P2 PIPE FLEX XRMS = 0.2087 / flexure rms in x-direction
# HIERARCH V500 PPAK P2 PIPE SPEC RES = 6.0 / FWHM in A of spectral resolution
# HIERARCH V500 PPAK P2 PIPE NSKY FIB = 30 / Number of averaged sky fibers
# HIERARCH V500 PPAK P2 PIPE SKY MEAN = 20.83 / Mean sky brightness of sky fibers
# HIERARCH V500 PPAK P2 PIPE SKY MIN = 20.7 / Minium sky brightness of sky fibers
# HIERARCH V500 PPAK P2 PIPE SKY MAX = 20.95 / Maximum sky brightness of sky fiber
# HIERARCH V500 PPAK P2 PIPE SKY RMS = 0.04 / RMS sky brightness of sky fibers
# HIERARCH V500 PPAK P2 PIPE CONT = 'run196_00954.fits' / Name of the continuum fr
# HIERARCH V500 PPAK P2 PIPE CONT MST = 0 / master TRACE used
# HIERARCH V500 PPAK P2 PIPE ARC = 'run196_00955.fits' / Name of the arc frame
# HIERARCH V500 PPAK P2 PIPE ARC MST = 0 / master ARC lamp used
# HIERARCH V500 PPAK P2 PIPE WOFFSET = 0.006 / wavelength offset of OI 5777 sky li
# HIERARCH V500 PPAK P2 PIPE WRMS = 0.064 / offset RMS of OI 5777 sky line
# HIERARCH V500 PIPE P2 APER FLUX = 5.929 / V_Johnson band flux (30.0arcsec diamet
# HIERARCH V500 PIPE P2 APER ERR = 0.065 / V_Johnson band error (30.0arcsec diamet
# HIERARCH V500 PIPE P2 RELFLUX START = 4500.0 / Start wave for poly fit
# HIERARCH V500 PIPE P2 RELFLUX END = 7000.0 / End wave for poly fit
# HIERARCH V500 PIPE P2 RELFLUX POLY0 = '1.000E+00' / Polynomial coefficient
# HIERARCH V500 PIPE P2 RELFLUX POLY1 = '3.907E-19' / Polynomial coefficient
# HIERARCH V500 PIPE P2 PIPE REGISTER = 1 / Possibilty of registering for this poi
# HIERARCH V500 PIPE P2 PIPE OFFX = -2.75 / IFU RA offset from ref coordinate
# HIERARCH V500 PIPE P2 PIPE OFFY = -4.5 / IFU DEC offset from ref coordinate
# HIERARCH V500 PIPE P2 PIPE CHISQ = 0.24 / CHISQ of image matching
# HIERARCH V500 PIPE P2 PIPE VALIDFIB = 318 / Valid fibers for image matching
# HIERARCH V500 PIPE P2 PIPE PHOTSCL = 0.879 / photometric scale factor
# HIERARCH V500 PPAK P3 LONGSTRN = 'OGIP 1.0' / The HEASARC Long String Convention
# HIERARCH V500 PPAK P3 PVERSION = '1.0     ' / PMAS fitsheader version
# HIERARCH V500 PPAK P3 FILENAME = 'run196_00958a.fits' / original filename
# HIERARCH V500 PPAK P3 DATE = '2011-09-25T23:37:20' / file creation
# HIERARCH V500 PPAK P3 OBSERVER = 'Montoya -- Sanchez'
# HIERARCH V500 PPAK P3 OBJECT = 'obj_5_p3_NGC 7819'
# HIERARCH V500 PPAK P3 CCD_TYPE = 'CCD231  '
# HIERARCH V500 PPAK P3 NAMPS = 4 / Number of Amplifiers
# HIERARCH V500 PPAK P3 NCCDS = 1 / Number of CCDs
# HIERARCH V500 PPAK P3 CAMPOS = -856.0 / camera position
# HIERARCH V500 PPAK P3 COLPOS = 99.0 / collimator position
# HIERARCH V500 PPAK P3 GROTPOS = 143.8 / grating position
# HIERARCH V500 PPAK P3 DEWAR = -117.072 / dewar temperature
# HIERARCH V500 PPAK P3 CALPOS = 120.0 / CAL actual position
# HIERARCH V500 PPAK P3 AGPOS = 3.1961E-05 / AG actual position
# HIERARCH V500 PPAK P3 FOCOLPOS = -8.2479900000000E-06 / FOCOL actual enc. positi
# HIERARCH V500 PPAK P3 FOFEPOS = 0.0 / FO Filter actual enc. position
# HIERARCH V500 PPAK P3 FOZPOS = 0.000331395 / FOZ stage actual enc. position
# HIERARCH V500 PPAK P3 FOCOLSL = 'none    ' / FO Collimator selection
# HIERARCH V500 PPAK P3 FOFESL = 'none    ' / FO Filter selection
# HIERARCH V500 PPAK P3 FIRST_AG = 16621 / A&G frame at begin of SPEC exposure
# HIERARCH V500 PPAK P3 DATE-OBS = '2011-09-25T23:37:20' / file creation
# HIERARCH V500 PPAK P3 POSTN-RA = 316.99 / tel. position Right Ascension
# HIERARCH V500 PPAK P3 RA = 1.320786 / 00:05:17.0 RA [deg]
# HIERARCH V500 PPAK P3 POSTN-DE = 113851.48 / tel. position Declination
# HIERARCH V500 PPAK P3 DEC = 31.62541 / +31:37:31.5 DEC [deg]
# HIERARCH V500 PPAK P3 POSTN-HA = 85176.39999999999 / tel. position Hour Angle
# HIERARCH V500 PPAK P3 HA = 354.901667 / 23:39:36.4 HA [deg]
# HIERARCH V500 PPAK P3 UNI-TIME = 85039.83 / Universal Time
# HIERARCH V500 PPAK P3 UTC = 85039.83302999999 / 23:37:19.8 U.T. at start [sec]
# HIERARCH V500 PPAK P3 UT_START = 85039.83302999999 / 23:37:19.8 U.T. at start [s
# HIERARCH V500 PPAK P3 SID-TIME = 85493.59 / Sidereal Time [sec]
# HIERARCH V500 PPAK P3 LST = 85493.587848 / 23:44:53.6 sid. time [sec]
# HIERARCH V500 PPAK P3 AIRMASS = 1.00753 / airmass
# HIERARCH V500 PPAK P3 JUL-DATE = 2455830.4863 / julian date
# HIERARCH V500 PPAK P3 MJD-OBS = 55829.98629316 / modified jul. date
# HIERARCH V500 PPAK P3 CAHA TEL GEOELEV = 2168 / elev. above sea
# HIERARCH V500 PPAK P3 CAHA TEL GEOLAT = 37.2236 / geographic lat.
# HIERARCH V500 PPAK P3 CAHA TEL GEOLON = -2.5463 / geographic long.
# HIERARCH V500 PPAK P3 CAHA TEL DOME.AZ = 345.7 / dome azimut [degr]
# HIERARCH V500 PPAK P3 CAHA TEL DOME.EL_LOW_E = 73.0 / dome door low lim.
# HIERARCH V500 PPAK P3 CAHA TEL DOME EL_UPP_E = 92.0 / dome door upper lim.
# HIERARCH V500 PPAK P3 CAHA TEL FOCU ID = 'CASS    ' / ID of used focus
# HIERARCH V500 PPAK P3 CAHA TEL MIRR S1 COLLAREA = 0.92 / eff. coll. area of S1 [
# HIERARCH V500 PPAK P3 CAHA TEL FOCU F_RATIO = 8.0 / f-ratio
# HIERARCH V500 PPAK P3 CAHA TEL FOCU LEN = 9.808 / focal length [m]
# HIERARCH V500 PPAK P3 CAHA TEL FOCU SCALE = 0.0478 / focus scale mm/arcsec
# HIERARCH V500 PPAK P3 CAHA TEL FOCU VALUE = 30.804 / focus rel. setting
# HIERARCH V500 PPAK P3 CAHA TEL POS SET RA = 495420.0 / 09:10:28.0 RA preset [sec
# HIERARCH V500 PPAK P3 CAHA TEL POS SET DEC = 46.439722 / +46:26:23.0 DEC preset
# HIERARCH V500 PPAK P3 CAHA TEL POS SET EQUINOX = 1950.0 / eq preset
# HIERARCH V500 PPAK P3 CAHA TEL POS AZ_START = 321.6 / telescope azimuth at start
# HIERARCH V500 PPAK P3 CAHA TEL POS EL_START = 83.0 / telescope elevation at star
# HIERARCH V500 PPAK P3 CAHA TEL POS HA_START = 354.901667 / 23:39:36.4 HA [deg]
# HIERARCH V500 PPAK P3 CAHA GEN AMBI WIND SPEED = 3.0 / wind-speed[m/s]
# HIERARCH V500 PPAK P3 CAHA GEN AMBI WIND DIR = 76 / wind dir[deg.]
# HIERARCH V500 PPAK P3 CAHA GEN AMBI RHUM = 50 / relative humidity[%]
# HIERARCH V500 PPAK P3 CAHA GEN AMBI PRES = 780.6 / air pressure
# HIERARCH V500 PPAK P3 CAHA GEN AMBI TEMP = 9.699999999999999 / air-temperature[C
# HIERARCH V500 PPAK P3 CAHA ADA POSANG = 0.06 / position angle of adapter
# HIERARCH V500 PPAK P3 XBIN = 2 / x binning
# HIERARCH V500 PPAK P3 YBIN = 2 / y binning
# HIERARCH V500 PPAK P3 ACEGAIN = 5 / ace gain
# HIERARCH V500 PPAK P3 CDSTIME = 1 / ace cds time
# HIERARCH V500 PPAK P3 EXPTIME = 900 / exposure time [s]
# HIERARCH V500 PPAK P3 EXPTIMEM = 0 / exposure time [ms]
# HIERARCH V500 PPAK P3 EXPTYPE = 1 / exposure type 0
# HIERARCH V500 PPAK P3 LMPSH_1 = 0 / shutter lamp 1 (Hal)
# HIERARCH V500 PPAK P3 LMPSH_2 = 0 / shutter lamp 2 (Ne)
# HIERARCH V500 PPAK P3 LMPSH_3 = 0 / shutter lamp 3 (Ne
# HIERARCH V500 PPAK P3 LMPSH_4 = 0 / shutter lamp 4 (Hg)
# HIERARCH V500 PPAK P3 LMPSH_5 = 0 / shutter lamp 5 (Hg)
# HIERARCH V500 PPAK P3 LMPSH_6 = 0 / shutter lamp 6 (ThAr)
# HIERARCH V500 PPAK P3 PPAK_SH3 = 0 / PPAK CALUNIT Shutter
# HIERARCH V500 PPAK P3 LMPOW_1 = 0 / power lamp 1 (Hal)
# HIERARCH V500 PPAK P3 LMPOW_23 = 0 / power lamp 2+3 (Ne)
# HIERARCH V500 PPAK P3 LMPOW_45 = 0 / power lamp 4+5 (Hg)
# HIERARCH V500 PPAK P3 LMPOW_6 = 0 / power lamp 6 (ThAr)
# HIERARCH V500 PPAK P3 POLUNIT = 0 / polarimetric mode 1
# HIERARCH V500 PPAK P3 POLANGL1 = 0.0 / polarimeter angle 1
# HIERARCH V500 PPAK P3 POLANGL2 = 22.5 / polarimeter angle 2
# HIERARCH V500 PPAK P3 GRAT_ID = 9 / grating id
# HIERARCH V500 PPAK P3 NFIBERS = 382 / number of fibers
# HIERARCH V500 PPAK P3 IFU_TYPE = 'PPAK_GenI.1_DIFU_331_36_15' / type of int. fie
# HIERARCH V500 PPAK P3 IFU_CONF = 'PPAK_GenI.1_DIFU_331_36_15.ifu' / configuratio
# HIERARCH V500 PPAK P3 PPAK_FIL = 'none    ' / PPAK IFU FORED Filter
# HIERARCH V500 PPAK P3 PPAK_CUF = 'none    ' / PPAK Calibration Unit Filter
# HIERARCH V500 PPAK P3 PPAK_SHO = 0.0 / PPAK Calibration Shutter open time
# HIERARCH V500 PPAK P3 LAST_AG = 16687 / A&G frame at end of SPEC exposure
# HIERARCH V500 PPAK P3 WARNING = 'Warning ' / RON & GAIN are measured unbinned!
# HIERARCH V500 PPAK P3 CAHA TEL POS AZ_END = 348.48 / telescope azimuth at end [d
# HIERARCH V500 PPAK P3 CAHA TEL POS EL_END = 84.3 / telescope elevation at end [d
# HIERARCH V500 PPAK P3 CAHA TEL POS HA_END = 358.665 / 23:54:39.6 HA [deg] at end
# HIERARCH V500 PPAK P3 UT_END = 85940.38303 / 23:52:20.4 U.T. [sec]
# HIERARCH V500 PPAK P3 EXPOSURE_TIME = 900.0 / s exposure time
# HIERARCH V500 PPAK P3 IMAGETYP = 'real    ' / bias,real,dark,test,ramp,bsw
# HIERARCH V500 PPAK P3 DETSIZE = '[1:4096,1:4112]' / physical detector size
# HIERARCH V500 PPAK P3 PRESCAN = '[50,0]  ' / additional real existent prescan pi
# HIERARCH V500 PPAK P3 CCDSEC = '[1:1055,1:1035]' / image location of amplifier
# HIERARCH V500 PPAK P3 AMP1 GAIN = 1.293 / Gain value of CCD amplifier 1
# HIERARCH V500 PPAK P3 AMP2 GAIN = 1.148 / Gain value of CCD amplifier 2
# HIERARCH V500 PPAK P3 AMP3 GAIN = 1.286 / Gain value of CCD amplifier 3
# HIERARCH V500 PPAK P3 AMP4 GAIN = 1.25 / Gain value of CCD amplifier 4
# HIERARCH V500 PPAK P3 AMP1 RDNOISE = 2.877 / Read-out noise of CCD amplifier 1
# HIERARCH V500 PPAK P3 AMP2 RDNOISE = 2.73 / Read-out noise of CCD amplifier 2
# HIERARCH V500 PPAK P3 AMP3 RDNOISE = 2.855 / Read-out noise of CCD amplifier 3
# HIERARCH V500 PPAK P3 AMP4 RDNOISE = 2.57 / Read-out noise of CCD amplifier 4
# HIERARCH V500 PPAK P3 AMP1 OVERSCAN = 363.0 / Overscan median (bias) of CCD ampl
# HIERARCH V500 PPAK P3 AMP2 OVERSCAN = 497.0 / Overscan median (bias) of CCD ampl
# HIERARCH V500 PPAK P3 AMP3 OVERSCAN = 551.0 / Overscan median (bias) of CCD ampl
# HIERARCH V500 PPAK P3 AMP4 OVERSCAN = 561.0 / Overscan median (bias) of CCD ampl
# HIERARCH V500 PPAK P3 HVCOR = 5.45 / Heliocentric vel correction [km/s]
# HIERARCH V500 PPAK P3 EXT_V = 0.17 / V-band atmospheric extinction
# HIERARCH V500 PPAK P3 EXT_V_SD = 0.0 / std of V-band atmospheric extinction
# HIERARCH V500 PPAK P3 PIPE FLEX YOFF = -0.08110000000000001 / flexure offset in
# HIERARCH V500 PPAK P3 PIPE FLEX YRMS = '0.0991  ' / flexure rms in y-direction
# HIERARCH V500 PPAK P3 PIPE CDISP FWHM MIN = 2.263823986053467
# HIERARCH V500 PPAK P3 PIPE CDISP FWHM MAX = 4.0
# HIERARCH V500 PPAK P3 PIPE CDISP FWHM AVG = 2.592828152939799
# HIERARCH V500 PPAK P3 PIPE CDISP FWHM MED = 2.528854846954346
# HIERARCH V500 PPAK P3 PIPE CDISP FWHM SIG = 0.2371905739189109
# HIERARCH V500 PPAK P3 PIPE DISP RMS MEDIAN = '0.0800  ' / Median RMS of disp sol
# HIERARCH V500 PPAK P3 PIPE DISP RMS MIN = '0.0224  ' / Min RMS of disp sol
# HIERARCH V500 PPAK P3 PIPE DISP RMS MAX = '0.4389  ' / Max RMS of disp sol
# HIERARCH V500 PPAK P3 PIPE FLEX XOFF = 0.002 / flexure offset in x-direction
# HIERARCH V500 PPAK P3 PIPE FLEX XRMS = 0.2197 / flexure rms in x-direction
# HIERARCH V500 PPAK P3 PIPE SPEC RES = 6.0 / FWHM in A of spectral resolution
# HIERARCH V500 PPAK P3 PIPE NSKY FIB = 30 / Number of averaged sky fibers
# HIERARCH V500 PPAK P3 PIPE SKY MEAN = 20.83 / Mean sky brightness of sky fibers
# HIERARCH V500 PPAK P3 PIPE SKY MIN = 20.75 / Minium sky brightness of sky fibers
# HIERARCH V500 PPAK P3 PIPE SKY MAX = 20.94 / Maximum sky brightness of sky fiber
# HIERARCH V500 PPAK P3 PIPE SKY RMS = 0.03 / RMS sky brightness of sky fibers
# HIERARCH V500 PPAK P3 PIPE CONT = 'run196_00954.fits' / Name of the continuum fr
# HIERARCH V500 PPAK P3 PIPE CONT MST = 0 / master TRACE used
# HIERARCH V500 PPAK P3 PIPE ARC = 'run196_00955.fits' / Name of the arc frame
# HIERARCH V500 PPAK P3 PIPE ARC MST = 0 / master ARC lamp used
# HIERARCH V500 PPAK P3 PIPE WOFFSET = 0.006 / wavelength offset of OI 5777 sky li
# HIERARCH V500 PPAK P3 PIPE WRMS = 0.064 / offset RMS of OI 5777 sky line
# HIERARCH V500 PIPE P3 APER FLUX = 5.657 / V_Johnson band flux (30.0arcsec diamet
# HIERARCH V500 PIPE P3 APER ERR = 0.065 / V_Johnson band error (30.0arcsec diamet
# HIERARCH V500 PIPE P3 RELFLUX START = 4500.0 / Start wave for poly fit
# HIERARCH V500 PIPE P3 RELFLUX END = 7000.0 / End wave for poly fit
# HIERARCH V500 PIPE P3 RELFLUX POLY0 = '1.101E+00' / Polynomial coefficient
# HIERARCH V500 PIPE P3 RELFLUX POLY1 = '-8.871E-06' / Polynomial coefficient
# HIERARCH V500 PIPE P3 PIPE REGISTER = 1 / Possibilty of registering for this poi
# HIERARCH V500 PIPE P3 PIPE OFFX = -2.5 / IFU RA offset from ref coordinate
# HIERARCH V500 PIPE P3 PIPE OFFY = -4.0 / IFU DEC offset from ref coordinate
# HIERARCH V500 PIPE P3 PIPE CHISQ = 0.21 / CHISQ of image matching
# HIERARCH V500 PIPE P3 PIPE VALIDFIB = 320 / Valid fibers for image matching
# HIERARCH V500 PIPE P3 PIPE PHOTSCL = 0.863 / photometric scale factor
# HIERARCH V500 OBJDESC GALAXY = 'Object description'
# AUTHOR  = 'CALIFA Collaboration' / Creator of the dataset
# INTRUME = 'PMAS/PPAK'          / Insturment use for observations
# HIERARCH PIPE VERS = 2.2 / Pipeline version
# HIERARCH PIPE UNITS = '1e-16 erg/s/cm^2/A' / flux unit
# OBJECT  = 'NGC7819 '           / Target object
# CALIFAID=                    3 / CALIFAID of object
# HIERARCH V500 PIPE REDUDATE = '28-06-2015T02:44:09' / Date/Time the file was pro
# HIERARCH V500 PIPE GALEXT COR = 1 / Applied Galactic Extinction (0 NO,1 Yes)
# HIERARCH V500 PIPE GALEXT AV = 0.187 / Galactic extinction in V-Band (-1 if not)
# CRVAL3  =               3749.0
# CDELT3  =                  2.0
# CRPIX3  =                  1.0
# CRVAL2  =    31.47187616999986 / DEC at CRPIX2 in deg
# CDELT2  =                  1.0
# CRPIX2  =                   33 / Ref pixel for WCS
# HIERARCH V500 INTCUBE = 'INVERSEDISTANCE' / Interpolation method to create the c
# HIERARCH V500 INTCUBEPARS = ' (sigma=0.75 | radius_limit=3.5 | min_fibers=1 )'
# WCSAXES =                    3 / Axes of the WCS
# WCSNAME = 'TELESCOPE'
# RADESYS = 'ICRS    '
# CTYPE1  = 'RA---TAN'           / Variable measured by the WCS
# CUNIT1  = 'deg     '           / Units
# CTYPE2  = 'DEC--TAN'           / Variable measured by the WCS
# CUNIT2  = 'deg     '           / Units
# CTYPE3  = 'WAVELENGTH'         / Spectral Axis Type
# CUNIT3  = 'Angstrom'           / Units
# CD1_1   = -0.00027777777777777 / Pixels in degress for X-axis
# CD1_2   =                  0.0
# CD2_1   =                  0.0
# CD2_2   = 0.000277777777777777 / Pixels in degress for Y-axis
# CD3_3   =                  2.0 / Linear dispersion (Angstrom/pixel)
# CD1_3   =                  0.0
# CD2_3   =                  0.0
# CD3_1   =                  0.0
# CD3_2   =                  0.0
# EQUINOX =               2000.0
# HIERARCH PIPE FILE VBAND = 'NGC7819.V.fits' / Synthetic V-band Fits image
# HIERARCH V500 DATE OBS = 20110925 / observation date
# FILENAME= 'NGC7819.V500.rscube.fits.gz' / File Name
# REGISTER=                    1 / Registering using SDSS images
# SDSSMAG = 'True    '           / Calculate SDSS 30arcsec aperture mag
# HIERARCH PIPE APER CUBE R = '14.115  ' / 30arcsec r band photometry from cube
# HIERARCH PIPE APER CUBE G = '14.645  ' / 30arcsec g band photometry from cube
# HIERARCH PIPE ABS SDSS FILE RATIO G = 0.9238468875379449 / ratio of SDSS photome
# HIERARCH PIPE ABS SDSS FILE RATIO R = 0.968277856261249 / ratio of SDSS photomet
# HIERARCH PIPE ABS SDSS FILE RATIO = 0.9460623718995969 / ratio of SDSS photometr
# HIERARCH APER FILE G = 14.731 / SDSS photometry (/home/sanchez/sda2/code/python/
# HIERARCH APER FILE R = 14.15 / SDSS photometry (/home/sanchez/sda2/code/python/c
# HIERARCH PIPE REDUDATE = '28-06-2015T02:47:06' / Date/Time the file was produced
# HIERARCH PIPE ABS SDSS PY3D RATIO G = 0.9246981739382218 / ratio of SDSS photome
# HIERARCH PIPE ABS SDSS PY3D RATIO R = 0.9727472237769657 / ratio of SDSS photome
# HIERARCH PIPE ABS SDSS PY3D RATIO = 0.9487226988575937 / ratio of SDSS photometr
# HIERARCH APER PY3D G = 14.73 / SDSS photometry (/home/sanchez/sda2/code/python/c
# HIERARCH APER PY3D R = 14.145 / SDSS photometry (/home/sanchez/sda2/code/python/
# HIERARCH MED_RATIO PSF SDSS = 0.1329188197851181 / factor median to match SDSS p
# KERNEL  = 'Moffat2D'           / Convolution Kernel used for the PSF
# FWHM    =                 1.56 / Best FHWM
# BETA    =    2.100000000000001 / Best BETA (Gaussian2D if None)
# HIERARCH SDSS FILTER = 'r       ' / Used SDSS Filter
# HIERARCH DRFIELD PSF_BETA = 3.449216842651367
# HIERARCH DRFIELD PSF_SIGMAP = 2.909637212753296
# HIERARCH DRFIELD PSF_WIDTH = 1.507877588272095
# HIERARCH FLAT_SDSS = T / SDSS Flat applied
# SHIFT1  =          0.880859375
# SHIFT2  =          0.705078125
# ORIG_RA =    1.101980207250066
# ORIG_DEC=    31.47168031528496
# WCS_COR =                    T
# HIERARCH PIPE FLAT APER CUBE R = '14.128  ' / 30arcsec r band photometry from cu
# HIERARCH PIPE FLAT ABS SDSS PY3D RATIO R = 0.9799411610955939 / ratio of SDSS ph
# HIERARCH PIPE FLAT ABS SDSS PY3D RATIO = 0.9341142557364792 / ratio of SDSS phot
# HIERARCH PIPE FLAT APER CUBE G = '14.657  ' / 30arcsec r band photometry from cu
# HIERARCH PIPE FLAT ABS SDSS PY3D RATIO G = 0.9341142557364792 / ratio of SDSS ph
# HIERARCH PIPE VMAG 3SIG = 23.63863327317792 / rough 3sigma depth (mag/arcsec**2)
# HIERARCH PIPE VMAG 5SIG = 23.47475586393729 / rough 3sigma depth (mag/arcsec**2)
# HIERARCH PIPE AREA 3SIG = 0.5795940170940171 / area (arcmin**2) above 3sigma lim
# MED_VEL =         4976.5548028 / systemic velocity km/s
# RMS_VEL =    9.580231124682387 / rms of systemic velocity (km/s)

# %% [markdown]
# Ahora haga un subplot que contemple 4 imágenes de la galaxia en 4 diferentes longitudes de onda de todo el espectro observado. Usted debe escoger estas cuatro longitudes de onda como se le antoje. Puede enchular los gráficos tanto como desee, es importante eso sí que todos contengan la información básica necesaria para que pueda ser visualizada científicamente. Recuerde importar los paquetes necesarios en caso de no haberlo hecho en algún bloque anterior.
#
# **Consejo**: Dentro de las longitudes de onda, se sugiere que escoja una cercana a los 6563 Angstrom.

# %%
# Primero se obtiene la imagen
data = hdu.data

# Luego se crea la figura con los subplots
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(20,20))

# Gráfico para long de onda 1
cb1=ax[0,0].imshow(data[0], origin='lower', vmax=0.6, vmin=0, cmap='viridis')
fig.colorbar(cb1, ax=ax[0,0], label='Flux [10$^{-16}$ erg/s/cm$^2$/$\AA$]')
ax[0,0].grid(b=None)
ax[0,0].set_xlabel('RA[deg]', size=20)
ax[0,0].set_ylabel('DEC[deg]', size=20)
ax[0,0].set_title('LONG 1', size=25, color='magenta')


# Gráfico para long de onda 2
cb2=ax[0,1].imshow(data[90], origin='lower', vmax=0.6, vmin=0, cmap='viridis')
fig.colorbar(cb2, ax=ax[0,1], label='Flux [10$^{-16}$ erg/s/cm$^2$/$\AA$]')
ax[0,1].grid(b=None)
ax[0,1].set_xlabel('RA[deg]', size=20)
ax[0,1].set_ylabel('DEC[deg]', size=20)
ax[0,1].set_title('LONG 2', size=25, color='magenta')


# Gráfico para long de onda 3
cb3=ax[1,0].imshow(data[40], origin='lower', vmax=0.6, vmin=0, cmap='viridis')
fig.colorbar(cb3, ax=ax[1,0], label='Flux [10$^{-16}$ erg/s/cm$^2$/$\AA$]')
ax[1,0].grid(b=None)
ax[1,0].set_xlabel('RA[deg]', size=20)
ax[1,0].set_ylabel('DEC[deg]', size=20)
ax[1,0].set_title('LONG 3', size=25, color='magenta')


# Gráfico para long de onda 4
cb4=ax[1,1].imshow(data[140], origin='lower', vmax=0.6, vmin=0, cmap='viridis')
fig.colorbar(cb4, ax=ax[1,1], label='Flux [10$^{-16}$ erg/s/cm$^2$/$\AA$]')
ax[1,1].grid(b=None)
ax[1,1].set_xlabel('RA[deg]', size=20)
ax[1,1].set_ylabel('DEC[deg]', size=20)
ax[1,1].set_title('LONG 4', size=25, color='magenta')
# Out:
# Text(0.5,1,'LONG 4')

# %% [markdown]
# #3. Espectros de la Galaxia
#
# Como saben, a cada pixel le corresponde un espectro. Ahora haga un subplot que contemple el espectro de 9 pixeles de la galaxia. 8 de los 9 pixeles deben ser escogidos al azar, mientras que uno de ellos debe corresponder al espectro de los pixeles de referencia que el header indica. Puede enchular los gráficos tanto como desee, es importante eso sí que todos contengan la información básica necesaria para que pueda ser visualizada científicamente. Recuerde importar los paquetes necesarios en caso de no haberlo hecho en algún bloque anterior.
#
# Finalmente calcule el redshift al cual se encuentra el objeto, para ello puede indentificar las líneas de los espectros obtenidos en esta [página](http://skyserver.sdss.org/dr15/en/tools/chart/navi.aspx). El cálculo del redshift debe hacerse con la información de los espectros del fits. Ignore la rotación de la galaxia.
#
# **Hint:** Le puede ser útil saber que la línea de H$\alpha$ se encuentra centrada en 6563 Angstroms. La longitud de onda de las primeras líneas de la serie de Balmer las puede encontrar en [aquí](https://es.wikipedia.org/wiki/L%C3%ADneas_de_Balmer). Imprima en pantalla la operación a realizar y que línea o líneas usó para determinar el redshift al cual se encuentra la galaxia.

# %% [markdown]
# #4. Coordenadas
#
# En esta parte deben crear una variable que contenga un objeto SkyCoord definido con los dos últimos dígitos de rut como ascención recta y declinación en el sistema ICRS (No contar el dígito verificador).
#
# **Ejemplo:** si su RUT es 12.345.678 - 9. La ascención recta y declinación para ese objeto debe ser 78°. Si los úlitmos dos dígitos son mayores que noventa, utilice solo el último.

# %% [markdown]
# #5. Query: Imagen
#
# En esta parte haga un query a los datos del SDSS utilizando como coordenadas las definidas anteriormente en una región de radio 10 arcsec, además, asegúrese que los objetos de la busqueda cuentan con un espectro. En caso de no encontrar algo, multiplique el radio por 2 hasta encontrar un objeto. Extraiga el espectro y la fotometría en las bandas z e i.
#
# Imprima en pantalla el WCS header de alguno de los fits fotometría, y proceda a graficar las regiones mostradas en los dos fits fotométricos descargados. Puede enchular los gráficos tanto como desee, es importante eso sí que todos contengan la información básica necesaria para que pueda ser visualizada científicamente. Como los datos son del SDSS, ustedes encontraran una imagen de la placa entera, hagan un zoom mostrando de forma cercana el objeto que les debiese haber salido al azar, queda a su criterio cuanto deben ampliar la imagen ustedes.

# %% [markdown]
# #6. Query: Espectro
#
# En esta parte haga un gráfico con los datos espectroscópicos del objeto encontrado. Imprima en pantalla el WCS header. Puede enchular los gráficos tanto como desee, es importante eso sí que todos contengan la información básica necesaria para que pueda ser visualizada científicamente. Compare el objeto con el encontrado en esta [página](http://skyserver.sdss.org/dr15/en/tools/chart/navi.aspx), identifique las líneas y hagan que se vean en el espectro bien señalizadas.
